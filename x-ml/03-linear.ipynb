# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# 设置中文字体为宋体或黑体
plt.rcParams["font.sans-serif"] = ["SimSong", "SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 代码要求
#
# **每项违规扣5分**
#
# - Matplotlib 绘图风格
#   - 使用 Object-Oriented API
#   - 使用 `ax.set()` 函数统一设置绘图属性
#   - 不使用 `plt.tight_layout()`
#   - 不使用 `plt.show()`
# - `print()`函数
#   - 使用`f-string`
#   - 只打印含有变量的信息
# - 只使用如下第三方包和版本
#   - Numpy > 2
#   - Pandas > 3
#   - Matplotlib > 3.11
#   - Scikit-Learn > 1.5
# - 未使用返回值以`_`命名
# - 不使用`df`或`data`命名 DataFrame
# - 不允许
#   - 有未使用变量
#   - 有未使用引入
#   - 重复引入
#   - 非必要打印

# %% [markdown]
# ## 作业要求
#
# 使用 Jupyter Notebook (.ipynb) 文件进行探索性数据分析（EDA），获取如下信息和完成相应任务，二级列表每项均为10分
#
# - 数据集概况
#   - 将特征、目标数据分别转换为Pandas类型，并指定列名
#   - 样本数、特征数
#   - 与目标相关性最高的特征
# - 特征可视化
#   - 绘制散点图：血压vs疾病发展
#   - 添加图标题、横轴、纵轴标题
# - 一元线性回归
#   - 使用一个特征，切分数据集，其中训练集占比80%
#   - 计算模型的MSE和$R^2$值
# - 多元线性回归
#   - 使用两个特征，训练模型
#   - 计算模型的MSE和$R^2$值
#   - 绘制1行2列的图表
#     - 子图1为一元线性回归，子图2为多元线性回归
#     - 真实值、预测值添加图例
#
# 作业以 .ipynb 文件提交，文件命名模式为：`03-学号-姓名.ipynb`。

# %%
# 加载糖尿病数据集

# 将特征转换为Pandas DataFrame

# 将目标变量转换为Pandas Series

# %% [markdown]
# ## 数据集概况

# %%
# 获取样本数和特征数

# 计算与目标相关性最高的特征

# %% [markdown]
# ## 特征可视化

# %%
# 绘制散点图：血压 vs 目标变量

# 创建图形和坐标轴

# 绘制散点图

# %% [markdown]
# ## 一元线性回归

# %%
# 使用与目标相关性最高的特征

# 选择相关性最高的特征作为自变量

# 切分数据集，训练集占比80%

# 创建并训练 LinearRegression 模型

# 预测测试集

# 计算平均误差损失（MSE）

# 计算 R² 值

# %% [markdown]
# ## 多元线性回归

# %%
# 获取相关性最高的两个特征

# 选择两个特征作为自变量

# 切分数据集

# 创建并训练多元线性回归模型

# 预测测试集

# 计算 R² 值

# %%
# 绘制1行3列的图表


# 创建1行3列的子图

# === 子图1：一元线性回归（特征1）===

# 准备特征1的数据


# 绘制散点图（真实值和预测值）


# === 子图2：一元线性回归（特征2）===


# 准备特征2的数据

# 绘制散点图


# === 子图3：多元线性回归 ===


# 绘制散点图（真实值vs预测值）

# 计算对角线范围


# 添加对角线

# 打印R²值汇总
