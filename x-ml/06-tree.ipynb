# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import (
    AdaBoostClassifier,
    BaggingClassifier,
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
    VotingClassifier,
)
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

# 设置中文字体为宋体或黑体
plt.rcParams["font.sans-serif"] = ["SimSong", "SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 代码要求
#
# **每项违规扣5分**
#
# - Matplotlib 绘图风格
#   - 使用 Object-Oriented API
#   - 使用 `ax.set()` 函数统一设置绘图属性
#   - 不使用 `plt.tight_layout()`
#   - 不使用 `plt.show()`
# - `print()`函数
#   - 使用`f-string`
#   - 只打印含有变量的信息
# - 只使用如下第三方包和版本
#   - Numpy > 2
#   - Pandas > 3
#   - Matplotlib > 3.11
#   - Scikit-Learn > 1.5
# - 未使用返回值以`_`命名
# - 不使用`df`或`data`命名 DataFrame
# - 不允许
#   - 有未使用变量
#   - 有未使用引入
#   - 重复引入
#   - 非必要打印

# %% [markdown]
# ## 作业要求
#
# 使用 Jupyter Notebook (.ipynb) 文件进行探索性数据分析（EDA），获取如下信息和完成相应任务，二级列表每项均为10分
#
# - 决策树
#   - 对比不同分裂准则的树生成，可视化树
#     - entropy
#     - gini
#     - log_loss
#   - 对比4种不同预剪枝策略下的模型准确率
#     - 无限制
#     - 最大深度限制
#     - 最小样本分裂限制
#     - 最小叶节点样本限制
# - 投票树
#   - 对比10、20、50棵决策树的Bagging分类得分
#   - 分别训练三个基学习器
#   - 对比硬投票和软投票策略的Voting分类得分
#   - 绘制硬投票和软投票的决策边界
# - 随机森林
#   - 对比使用全部特征Bagging和随机森林的分类得分
#   - 对比随机森林和极端随机树的分类得分
# - 提升树
#   - 可视化50棵树的AdaBoost：准确率vs迭代次数
#   - 可视化50棵树的GBDT：准确率vs迭代次数
#
# 作业以 .ipynb 文件提交，文件命名模式为：`06-学号-姓名.ipynb`。

# %%
X, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_redundant=0,
    n_informative=2,
    n_classes=2,
    random_state=42,
    n_clusters_per_class=2,
)
features = pd.DataFrame(X, columns=["feature_1", "feature_2"])
target = pd.Series(y, name="target")

# 切分数据集，test_size=0.3，random_state=42


# 在此填写代码：使用 f-string 打印训练集和测试集样本数

# %% [markdown]
# ## 决策树

# %% [markdown]
# ### 不同分裂准则

# %%
# 在此填写代码：创建使用gini准则的决策树模型


# 在此填写代码：创建使用entropy准则的决策树模型

# 在此填写代码：训练模型


# 在此填写代码：计算并打印模型在测试集上的准确率

# 可视化对比
# 在此填写代码：创建图形


# 在此填写代码：使用 plot_tree 绘制三棵树的结构（max_depth=3）


# 在此填写代码：设置标题并显示图形

# %% [markdown]
# ### 不同预剪枝策略

# %%
# 在此填写代码：定义4种预剪枝策略的参数列表
# 1. 无剪枝：{}
# 2. 最大深度限制
# 3. 最小样本分裂限制
# 4. 最小叶节点样本限制


# 在此填写代码：创建图形

# 在此填写代码：使用 for idx, (name, params) in enumerate(pruning_strategies) 循环
# 创建模型 DecisionTreeClassifier(random_state=42, **params)

# 训练模型

# 计算训练集和测试集准确率

# 绘制树结构


# 在此填写代码：设置总标题并显示图形

# %% [markdown]
# ## 投票树

# %%
clf1 = LogisticRegression(random_state=1)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)
clf3 = BaggingClassifier(DecisionTreeClassifier(), n_estimators=50, random_state=1)
estimators = [("lr", clf1), ("rf", clf2), ("dt", clf3)]

# 在此填写代码：分别训练三个基学习器


# 在此填写代码：计算并打印三个基学习器的测试准确率

# %% [markdown]
# ### 硬投票vs软投票

# %%
# 在此填写代码：创建硬投票模型 model_hard = VotingClassifier(estimators, voting='hard')

# 在此填写代码：创建软投票模型 model_soft = VotingClassifier(estimators, voting='soft')

# 在此填写代码：训练两个投票模型


# 在此填写代码：计算并打印硬投票和软投票的测试准确率


# 决策边界可视化
# 在此填写代码：创建图形

# 在此填写代码：绘制训练集和测试集散点图

# 在此填写代码：决策边界

# %% [markdown]
# ## 随机森林

# %% [markdown]
# ### 使用全部特征Bagging和随机森林

# %%
X_rf, y_rf = make_classification(
    n_samples=1000,
    n_features=10,
    n_redundant=0,
    n_informative=10,
    n_classes=2,
    random_state=42,
)

# 在此填写代码：创建全特征Bagging模型（使用全部特征，即max_features=1.0）


# 在此填写代码：创建随机森林模型


# 在此填写代码：训练两个模型


# 在此填写代码：计算并打印两个模型的测试准确率

# %% [markdown]
# ### 随机森林和极端随机树

# %%
# 在此填写代码：创建随机森林模型


# 在此填写代码：创建极端随机树模型


# 在此填写代码：训练两个模型


# 在此填写代码：计算并打印两个模型的测试准确率

# %% [markdown]
# ## 提升树

# %% [markdown]
# ### AdaBoost

# %%
# 在此填写代码：创建AdaBoost模型


# 在此填写代码：训练模型

# 在此填写代码：获取 staged_predict 结果，计算每轮的训练和测试准确率

# 可视化
# 在此填写代码：创建图形

# 在此填写代码：绘制训练准确率曲线（蓝色）


# 在此填写代码：绘制测试准确率曲线（红色）

# 在此填写代码：使用 ax.set() 设置

# 在此填写代码：使用 ax.legend() 和 ax.grid(True, alpha=0.3)

# %% [markdown]
# ### GBDT

# %%
# 在此填写代码：创建GBDT模型

# 在此填写代码：训练模型

# 在此填写代码：获取 staged_predict 结果，计算每轮的训练和测试准确率

# 可视化
# 在此填写代码：创建图形

# 在此填写代码：绘制训练准确率曲线（蓝色）

# 在此填写代码：绘制测试准确率曲线（红色）

# 在此填写代码：使用 ax.set() 设置

# 在此填写代码：使用 ax.legend() 和 ax.grid(True, alpha=0.3)
