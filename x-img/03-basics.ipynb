# %% [markdown]
# # 图像基本操作
#
# ## 代码规范
#
# - Matplotlib 绘图风格
#   - 使用 Object-Oriented API
#   - 使用 `ax.set()` 函数统一设置绘图属性
#   - 不使用 `plt.show()`
#   - 不实用 `plt.tight_layout()`
# - `print()`函数
#   - 使用`f-string`
#   - 只打印含有变量的信息
# - 未使用变量以`_`命名
# - 只使用如下第三方包和版本
#   - Numpy > 2
#   - Pandas > 3
#   - Matplotlib > 3.11
#   - OpenCV > 4.9
# - 不允许
#   - 有未使用变量
#   - 有未使用引入
#   - 重复引入
#   - 非必要打印
#   - 使用表情

# %% [markdown]
# ## 作业要求
#
# 使用 Jupyter Notebook (.ipynb) 文件进行探索性数据分析（EDA），获取如下信息和完成相应任务，二级列表每项均为10分
#
# - 图形元素的绘制
#   - 圆形、矩形、多边形
#   - 文字
# - 图像通道
#   - 拆分与合并
#   - 色彩变换（BGR->RGB）
#   - 色彩变换（彩色->灰度）
# - 图像的运算
#   - 图像的加法和乘法
#   - 图像的逻辑运算
# - 图像几何变换
#   - 翻转
#   - 旋转
#   - 仿射变换

# %% [markdown]
# ## 环境准备

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 设置中文字体
plt.rcParams["font.sans-serif"] = ["SimSong", "SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 第一部分：图形元素的绘制

# %% [markdown]
# ### 1.1 圆形、矩形、多边形绘制
#
# **题目要求**：
#
# 创建一个黑色背景图像（400×400像素），完成以下绘制：
#
# 1. 绘制一个**红色实心圆**：圆心位于(100,100)，半径为50
# 2. 绘制一个**绿色矩形**：左上角(200,50)，右下角(350,150)，线宽为3
# 3. 绘制一个**蓝色三角形**：顶点为(200,200)、(300,300)、(100,300)，线宽为3
#
# 使用 Matplotlib 显示最终结果。
#
# **提示函数**：`cv2.circle()`, `cv2.rectangle()`, `cv2.polylines()`, `np.zeros()`

# %%
# TODO: 在此编写代码

# 创建黑色背景图像

# 绘制红色实心圆

# 绘制绿色矩形

# 绘制蓝色三角形

# 使用OO-API显示结果
fig, ax = plt.subplots(figsize=(8, 8))
# ax.imshow(...)
# ax.set(...)...

# %% [markdown]
# ### 1.2 文字绘制
#
# **题目要求**：
#
# 1. 创建白色背景图像（400×600像素）
# 2. 在图像上绘制文字 **"OpenCV Image Processing"**
# 3. 要求：
#    - 位置：(50, 350)
#    - 字体：`cv2.FONT_HERSHEY_SIMPLEX`
#    - 大小：1
#    - 颜色：黄色
#    - 线宽：2

# %%
# TODO: 在此编写代码

# 创建白色背景图像

# 设置文字参数

# 绘制文字

# 使用OO-API显示
fig, ax = plt.subplots(figsize=(10, 6))
# ax.imshow(...)
# ax.set(...)

# %% [markdown]
# ## 第二部分：图像通道

# %% [markdown]
# ### 2.1 通道拆分与合并
#
# **题目要求**：
#
# 1. 创建或读取一张彩色图像
# 2. 使用OpenCV将图像**拆分为B、G、R三个通道**
# 3. 使用 Matplotlib 分别显示原图和三个通道（使用灰度图显示通道）
# 4. 将三个通道**重新合并**为彩色图像，验证合并结果与原图一致
#
# 使用2×2子图布局显示。
#
# **提示函数**：`cv2.split()`, `cv2.merge()`

# %%
# TODO: 在此编写代码

# 创建或读取彩色图像

# 通道拆分

# 使用OO-API创建2x2子图
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# 使用ax.set()设置每个子图

# %% [markdown]
# ### 2.2 色彩变换 BGR→RGB
#
# **题目要求**：
#
# 1. 解释为什么OpenCV使用BGR格式而Matplotlib使用RGB格式
# 2. 使用**两种不同方法**将BGR图像转换为RGB格式：
#    - 方法1：使用`cv2.cvtColor()`
#    - 方法2：使用NumPy索引操作
# 3. 使用 Matplotlib 对比显示转换前后的图像
# 4. 验证两种方法结果相同
#
# **提示**：NumPy索引`[::-1]`可以用于反转通道顺序

# %%
# TODO: 在此编写代码

# 创建BGR测试图像

# 方法1：使用cv2.cvtColor()

# 方法2：使用NumPy索引

# 使用OO-API对比显示
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# %% [markdown]
# ### 2.3 色彩变换 彩色→灰度
#
# **题目要求**：
#
# 1. 将彩色图像转换为灰度图像，使用**两种方法**：
#    - 方法1：使用`cv2.cvtColor()`（标准方法）
#    - 方法2：手动计算灰度值（使用加权公式：Gray = 0.299×R + 0.587×G + 0.114×B）
# 2. 使用 Matplotlib 显示对比结果
#
# **提示函数**：`cv2.cvtColor()`（参数`COLOR_BGR2GRAY`）

# %%
# TODO: 在此编写代码

# 创建彩色测试图像

# 方法1：使用cv2.cvtColor()

# 方法2：手动计算（加权公式）

# 使用OO-API显示对比结果
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# %% [markdown]
# ## 第三部分：图像的运算

# %% [markdown]
# ### 3.1 图像的加法和乘法
#
# **题目要求**：
#
# 创建两张200×200的测试图像，完成以下操作：
#
# 1. **直接加法**：使用`cv2.add()`将两张图像相加
# 2. **加权加法**：使用`cv2.addWeighted()`按0.6:0.4的比例融合两张图像
# 3. **标量乘法**：将第一张图像的所有像素值乘以1.5
# 4. **矩阵乘法**：两张图像逐元素相乘（注意处理数值范围）
#
# 要求：
# - 使用 Matplotlib 显示原图和四种运算结果
# - **说明**：`cv2.add()`与NumPy直接相加`img1 + img2`的区别
# - **说明**：如何处理乘法运算的溢出问题？
#
# **提示函数**：`cv2.add()`, `cv2.addWeighted()`, `cv2.multiply()`

# %%
# TODO: 在此编写代码

# 创建两张测试图像

# 1. 直接加法

# 2. 加权加法

# 3. 标量乘法

# 4. 矩阵乘法

# 使用OO-API显示所有结果
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# %% [markdown]
# ### 3.2 图像的逻辑运算
#
# **题目要求**：
#
# 创建两张200×200的二值图像（一张含矩形，一张含圆形），完成以下逻辑运算：
#
# 1. **按位与**（AND）：`cv2.bitwise_and()`
# 2. **按位或**（OR）：`cv2.bitwise_or()`
# 3. **按位非**（NOT）：`cv2.bitwise_not()`（对第一张图操作）
# 4. **按位异或**（XOR）：`cv2.bitwise_xor()`
#
# **实际应用**：展示如何使用圆形掩膜从彩色图像中提取圆形区域（ROI）。
#
# 使用 Matplotlib 显示所有结果。
#
# **提示函数**：`cv2.bitwise_and()`, `cv2.bitwise_or()`, `cv2.bitwise_not()`, `cv2.bitwise_xor()`

# %%
# TODO: 在此编写代码

# 创建二值图像（矩形和圆形）

# 按位与

# 按位或

# 按位非

# 按位异或

# 使用OO-API显示逻辑运算结果
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# 实际应用：掩膜提取ROI
fig2, axes2 = plt.subplots(1, 3, figsize=(15, 5))

# %% [markdown]
# ## 第四部分：图像几何变换

# %% [markdown]
# ### 4.1 图像翻转
#
# **题目要求**：
#
# 创建一张带文字和箭头的测试图像，实现以下翻转：
#
# 1. **水平翻转**（左右镜像）
# 2. **垂直翻转**（上下颠倒）
# 3. **同时水平和垂直翻转**（等效于180度旋转）
#
# 使用`cv2.flip()`函数，使用 Matplotlib 显示原图和三种翻转结果。
#
# **说明**：`flipCode`参数的三个取值（0, 1, -1）分别代表什么？

# %%
# TODO: 在此编写代码

# 创建带文字和箭头的测试图像

# 水平翻转

# 垂直翻转

# 同时水平和垂直翻转

# 使用OO-API显示结果
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# %% [markdown]
# ### 4.2 图像旋转
#
# **题目要求**：
#
# 对图像进行旋转操作：
#
# 1. 绕图像中心旋转**45度**，保持原图尺寸（观察裁剪效果）
# 2. 绕图像中心旋转**90度**
# 3. 绕图像中心旋转**45度**，自适应调整输出尺寸（不裁剪完整图像）
#
# 要求：
# - 使用`cv2.getRotationMatrix2D()`获取旋转矩阵
# - 使用`cv2.warpAffine()`执行旋转
# - 解释旋转矩阵的参数含义（center, angle, scale）
#
# **提示**：自适应边界需要重新计算输出图像的宽度和高度

# %%
# TODO: 在此编写代码

# 创建测试图像

# 获取图像尺寸和中心点

# 旋转45度（保持尺寸）

# 旋转90度

# 旋转45度（自适应边界）

# 使用OO-API显示结果
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# %% [markdown]
# ### 4.3 仿射变换
#
# **题目要求**：
#
# 实现以下三种仿射变换：
#
# 1. **平移变换**：将图像向右平移50像素，向下平移30像素
#    - 构造平移矩阵`[[1,0,50], [0,1,30]]`
#
# 2. **剪切变换**：实现水平剪切（shear），剪切因子为0.3
#    - 构造剪切矩阵`[[1,0.3,0], [0,1,0]]`
#
# 3. **自定义仿射变换**：使用三点对应法
#    - 原图三点：(100,100), (200,100), (100,200)
#    - 目标三点：(80,120), (220,110), (120,230)
#    - 使用`cv2.getAffineTransform()`计算变换矩阵
#
# 要求：
# - 使用`cv2.warpAffine()`执行所有变换
# - 使用 Matplotlib 显示原图和三种变换结果

# %%
# TODO: 在此编写代码

# 创建测试图像

# 1. 平移变换

# 2. 剪切变换

# 3. 自定义仿射变换（三点对应）

# 使用OO-API显示结果
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
