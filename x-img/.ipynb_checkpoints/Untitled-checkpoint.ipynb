// %%
#include <iostream>

// %%
#pragma cling add_library_path("/usr/local/lib")

// %%
#pragma cling load("/usr/local/lib/libdlib.so")

// %%
#pragma cling add_include_path("/Users/integzz/.conda/envs/cpp/include")

// %%
#pragma cling add_include_path("/Users/integzz/.conda/envs/cpp/include/opencv4")

// %%
#pragma cling add_include_path("/Users/integzz/.conda/envs/cpp/include/opencv4/opencv2")

// %%
#include <opencv2/opencv.hpp>
// Out:
// In file included from <<< inputs >>>:1:
// input_line_8:1:10: fatal error:
//       'opencv2/opencv.hpp' file not found
//     1 | #include <opencv2/opencv.hpp>
//       |          ^~~~~~~~~~~~~~~~~~~~
// Failed to parse via ::process:Parsing failed.
// Error: Compilation error! In file included from <<< inputs >>>:1:
// input_line_8:1:10: fatal error:
//       'opencv2/opencv.hpp' file not found
//     1 | #include <opencv2/opencv.hpp>
//       |          ^~~~~~~~~~~~~~~~~~~~
// Failed to parse via ::process:Parsing failed.

// %%
using namespace std;

// %%
std::cout << "Hello, World!" << std::endl;

// %%
using namespace cv;

// %%
std::cout << "OpenCV Version: " << CV_VERSION << std::endl;
