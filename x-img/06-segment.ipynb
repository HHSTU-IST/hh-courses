# %% [markdown]
# # 图像分割

# %% [markdown]
# ## 代码要求
#
# 违反代码要求一律不得分
#
# - Matplotlib 绘图风格
#   - 使用 Object-Oriented API
#   - 使用 `ax.set()` 函数统一设置绘图属性
#   - 不使用 `plt.show()`
#   - 不使用 `plt.tight_layout()`
# - `print()`函数
#   - 使用`f-string`
#   - 只打印含有变量的信息
# - 只使用如下第三方包和版本
#   - Numpy > 2
#   - Pandas > 3
#   - Matplotlib > 3.11
#   - Scikit-Image > 0.25
#   - OpenCV > 4.9
# - Markdown Cell
#   - 将一级列表内容作为二级标题
#   - 将作业要求放在文件开头
# - 不允许
#   - 有未使用变量（未使用变量以`_`命名）
#   - 有未使用引入
#   - 重复引入
#   - 非必要打印
#   - 使用表情

# %% [markdown]
# ## 作业要求
#
# 使用 Jupyter Notebook (.ipynb) 文件进行探索性数据分析（EDA），获取如下信息和完成相应任务，二级列表每项均为10分
#
# - 金字塔分割
#   - Laplacian 金字塔
#   - Gaussian 金字塔
# - 角点检测
#   - Harris 法
#   - Shi-Tomasi 法
#   - FAST 法
#   - Blob 法
# - 关键点检测
#   - SIFT
#   - FAST
# - 特征匹配
#   - FLANN 法
#   - ORB 法
# - 图片使用 `scikit-image` 内置图片
#
# 作业以 .ipynb 文件提交，文件命名模式为：`06-学号-姓名.ipynb`。

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.sans-serif"] = ["SimSong", "SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 金字塔分割

# %% [markdown]
# ### Laplacian 金字塔
#
# 实现 Laplacian 金字塔的构建与重建，展示每层图像

# %%
# TODO: 读取图像并构建 Laplacian 金字塔
# 提示：使用 cv2.pyrDown 和 cv2.subtract

# %% [markdown]
# ### Gaussian 金字塔
#
# 实现 Gaussian 金字塔的构建，展示下采样过程

# %%
# TODO: 构建 Gaussian 金字塔并可视化各层

# %% [markdown]
# ## 角点检测

# %% [markdown]
# ### Harris 法
#
# 使用 Harris 角点检测算法检测图像角点，并标记检测结果

# %%
# TODO: 实现 Harris 角点检测
# 提示：使用 cv2.cornerHarris

# %% [markdown]
# ### Shi-Tomasi 法
#
# 使用 Shi-Tomasi (goodFeaturesToTrack) 算法检测角点

# %%
# TODO: 实现 Shi-Tomasi 角点检测
# 提示：使用 cv2.goodFeaturesToTrack

# %% [markdown]
# ### FAST 法
#
# 使用 FAST 算法进行角点检测，比较与其他方法的性能差异

# %%
# TODO: 实现 FAST 角点检测
# 提示：使用 cv2.FastFeatureDetector_create()

# %% [markdown]
# ### Blob 法
#
# 使用 SimpleBlobDetector 检测图像中的 Blob 特征

# %%
# TODO: 实现 Blob 检测
# 提示：使用 cv2.SimpleBlobDetector_create()

# %% [markdown]
# ## 关键点检测

# %% [markdown]
# ### SIFT
#
# 使用 SIFT 算法检测和描述关键点，绘制关键点方向

# %%
# TODO: 实现 SIFT 关键点检测与描述
# 提示：使用 cv2.SIFT_create()

# %% [markdown]
# ### FAST

# %%
# TODO: 实现或说明 FAST

# %% [markdown]
# ## 特征匹配

# %% [markdown]
# ### FLANN 法
#
# 使用 FLANN 匹配器对两幅图像的 SIFT 特征进行匹配

# %%
# TODO: 实现 FLANN 特征匹配
# 提示：使用 cv2.FlannBasedMatcher

# %% [markdown]
# ### ORB 法
#
# 使用 ORB 特征检测器和 BFMatcher 进行特征匹配

# %%
# TODO: 实现 ORB 特征检测与匹配
# 提示：使用 cv2.ORB_create() 和 cv2.BFMatcher
